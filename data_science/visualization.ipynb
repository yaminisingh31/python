# %%
1080*1920*3
# Out:
# 6220800

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
a=np.ones(6220800,dtype=np.uint8).reshape(1080,1920,3)*255
a[:360,:,:]=[255,150,51]
a[360:720,:,:]=[255,255,255]
area=a[360:720,640:1280,:]=[0,0,0]
a[720:,:,:]=[0,255,0]
plt.imshow(a)
plt.show()

# %%
x=np.linspace(-5,5,1000)

# %%
x_sq=x**2
x_cub=x**3
x_sqrt=np.sqrt(x)
x_exp=np.exp(x)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot(x,x,'r--')
plt.plot(x,x_exp,'m-',label="exponenetial",lw=3)
plt.legend()
plt.show()

# %%
y=np.sqrt(100-x_sq)

# %%
plt.plot(x,y)

# %%
#figure
import statistics as stat

# %%
fig=plt.figure(figsize=(10,3))
#ax1=fig.add_axes([0,0,1,1])#reference axes
ax2=fig.add_axes([0.1,0.6,0.3,0.3])
ax3=fig.add_axes([0.1,0.1,0.3,0.3])
ax4=fig.add_axes([0.6,0.1,0.3,0.3])
ax5=fig.add_axes([0.6,0.6,0.3,0.3])
ax2.plot(x,x,label="$x$")
ax2.legend()
ax2.plot(x,x_sq,label="$x^2$")
ax2.legend()
ax2.plot(x,x_cub,label="$x^3$")
ax2.legend()
ax5.plot(x,x_exp)
ax5.plot(x,np.log(x))
ax3.plot(x,6*x**2+3*x+5,'m-',label="$6x^2 + 3 x +5$")
ax3.legend()
ax4.plot(x,abs(x),'m--',label="$|x|$")
ax4.legend()
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in log

# %%
fig=plt.figure(figsize=(5,5))
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.1,0.5,0.3,0.3])
ax1.plot(x,x,'ro')
ax2.plot(x,x_sq)
ax2.plot(x,x_cub)
plt.show()

# %%
#subplot
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)#3#4
plt.show()

# %%
#tuple unpacking

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(2,2,figsize=(10,5),sharey=True)
ax1.plot(x,x)
ax2.plot(x,x**3,label="$x^3$");ax2.legend()
ax2.set_xticks(range(0,20,2))#with axes use set_xticks or y_ticks
ax3.plot(x,x**2,label="$x^2$");ax3.legend()
ax4.plot(x,np.abs(x),label="$|x|$");ax4.legend()

# %%
help(plt.legend)
# Out:
# Help on function legend in module matplotlib.pyplot:
#
# legend(*args, **kwargs)
#     Places a legend on the axes.
#
#     Call signatures::
#
#         legend()
#         legend(labels)
#         legend(handles, labels)
#
#     The call signatures correspond to three different ways how to use
#     this method.
#
#     **1. Automatic detection of elements to be shown in the legend**
#
#     The elements to be added to the legend are automatically determined,
#     when you do not pass in any extra arguments.
#
#     In this case, the labels are taken from the artist. You can specify
#     them either at artist creation or by calling the
#     :meth:`~.Artist.set_label` method on the artist::
#
#         line, = ax.plot([1, 2, 3], label='Inline label')
#         ax.legend()
#
#     or::
#
#         line.set_label('Label via method')
#         line, = ax.plot([1, 2, 3])
#         ax.legend()
#
#     Specific lines can be excluded from the automatic legend element
# ...

# %%
x=np.arange(0,11)
plt.plot(x,x+10,label="legend");plt.legend()
plt.title("Hello world to matplot",fontsize=12)
plt.xlabel("hello i m x label")
plt.ylabel("hello i m y axis")
plt.xticks(x)
plt.yticks(x+10)
plt.grid()

plt.show()

# %%
angle=np.arange(0,361,15)
rad=np.deg2rad(angle)

# %%
sin=np.sin(rad)
cos=np.cos(rad)

# %%
plt.figure(figsize=(10,10))
plt.plot(angle,sin,label="sin")
plt.plot(angle,cos,label="cos")
plt.legend()
plt.xlabel("Angle",fontsize="20")
plt.ylabel("Values",fontsize="20")
plt.grid()
plt.title("Sin And Cos ",fontsize="20")
plt.xticks(range(0,361,15))
plt.yticks([-2,-1,0,1,2])
plt.savefig("Graph.png")

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(-5,5,1000)

# %%
mod_x=abs(x)

# %%
plt.plot(x,mod_x,'b--',label="$|x|$",lw=2)
plt.legend()
plt.show()

# %%
x_sq=x**2
x_cube=x**3
x_exp=np.exp(x)
x_log=np.log(x)
x_sqrt=np.sqrt(x)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log
#   after removing the cwd from sys.path.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """

# %%
plt.plot(x,x_sq,label="Square")
plt.plot(x,x_cube,label="Cube")
plt.plot(x,x_exp,label="exponential")
plt.plot(x,x_log,label="logarithmic")
plt.plot(x,x_sqrt,label="square root")
plt.legend()
plt.show()

# %%
y=np.sqrt(100-x_sq)

# %%
plt.plot(x,y)
plt.show()

# %%
#figure

# %%
fig=plt.figure(figsize=(5,5))
ax1=fig.add_axes([0,0,1,1])#reference axis
ax2=fig.add_axes([0.4,0.4,0.4,0.4])
ax2.plot(x,x_sq,label="Square",lw=2)

ax2.legend()
plt.show(fig)

# %%
fig=plt.figure(figsize=(5,6))
#ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.1,0.1,0.3,0.3])
ax3=fig.add_axes([0.6,0.1,0.3,0.3])
ax4=fig.add_axes([0.1,0.6,0.3,0.3])
ax5=fig.add_axes([0.6,0.6,0.3,0.3])
ax5.plot(x,x_sq,'r--',label="Square",lw=3)
ax5.legend()
ax4.plot(x,x_log,'g.',label="logarithmic",lw=3)
ax4.legend()
ax3.plot(x,x_cube,'m:',label="Cube",lw=3)
ax3.legend()

ax2.plot(x,x_exp,'b-',label="exponential",lw=3)
ax2.legend()
plt.show()

# %%
fig=plt.figure(figsize=(5,5))
ax1=fig.add_subplot(221)
ax2=fig.add_subplot(224)
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(2,2,figsize=(5,5),sharey=True)
ax3.set_xticks(range(0,50,5))
ax3.set_yticks(range(0,10))
ax1.set_yticks(range(0,10))
plt.show()

# %%
plt.figure(figsize=(5,10))
angle=np.arange(0,361,15)
rad=np.deg2rad(angle)
sin=np.sin(rad)
cos=np.cos(rad)
plt.plot(angle,sin,'g--',label="Sin",lw=3);plt.legend()
plt.plot(angle,cos,'r-',label="Cos",lw=3);plt.legend()
plt.title("Sin And Cos",fontsize=20)
plt.xlabel("Angle",fontsize="20")
plt.ylabel("Values",fontsize="20")

plt.grid()
plt.savefig("two.png")
plt.show()
